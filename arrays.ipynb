# %%
#sum of array
arr=[1,2,3,4,5]
sum=0
for i in range(len(arr)):
    sum+=arr[i]
print("Sum of the elements of the array :",sum)
# Out:
# Sum of the elements of the array : 15

# %%
#Reverse an array
arr=[1,2,3,4,5,6]
i=0
j=len(arr)-1
while i<=j:
    arr[i],arr[j]=arr[j],arr[i]
    i+=1
    j-=1
print(arr)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
#largest element of an array
arr=[90,78,34,12,45,92]
mx=arr[0]
for i in range(1,len(arr)):
    if mx<arr[i]:
        mx=arr[i]
print("Largest element of the array is",mx)
# Out:
# Largest element of the array is 92

# %%
#Mean of array
arr=[23,45,2,18,20]
sum=0
n=len(arr)
for i in range(len(arr)):
    sum+=arr[i]
print("Mean of array:",sum//n)
# Out:
# Mean of array: 21

# %%
#second largest element of the array
arr=[34,92,40,12,90,5]
mx=arr[0]
smx=-1
for i in range(1,len(arr)):
    if mx<arr[i]:
        smx,mx=mx,arr[i]
    elif mx>arr[i] and smx<arr[i]:
        smx=arr[i]
print("Second largest element of the array:",smx)
# Out:
# Second largest element of the array: 90

# %%
#check if array is sorted in non decreasing order
arr=[2,4,7,10,1]
def check_sort(ar):
    for i in range(1,len(ar)):
        if ar[i]>ar[i-1]:
            continue
        else:
            return False
    return True
check_sort(arr)
# Out:
# False

# %%
#remove duplicates from sorted array
arr=[1,1,2,2,2]
res=[arr[0]]
for i in range(1,len(arr)):
    if arr[i]!=arr[i-1]:
        res.append(arr[i])
print(res)
# Out:
# [1, 2]

# %%
#Count the maximum number of consectuive bits 0's and 1's 
arr=[0,0,0,1,1,0,0,1]
mx=1
c=1
for i in range(1,len(arr)):
    if arr[i]==arr[i-1]:
        c+=1
        mx=max(mx,c)
    else:
        c=1
print("Maximum number of consectuive bits",mx)
# Out:
# Maximum number of consectuive bits 3

# %%
#smallest and second smallest element in the array . return -1 if no second smallest no present
arr=[2,4,3,5,8]
res=[]
if len(arr) < 2:
    res.append(-1)
first = float('inf')
second = float('inf')
for num in arr:
    if num < first:
        second = first
        first = num
    elif first < num < second:
        second = num
if second == float('inf'):
    res.append(-1)
    print(res)
else:
    res.extend([first, second])
    print(res)
# Out:
# [2, 3]

# %%
#array subset
A=[2,3,6,10,2,4,3]
B=[3,4]
A.sort()
B.sort()
i=0
j=0
while(i<len(A) and j<len(B)):
    if A[i]==B[j]:
        i+=1
        j+=1
    else:
        i+=1
if j==len(B):
    print(True)
else:
    print(False)
# Out:
# True

# %%
#rotate array
arr=[3,9,7,1]
d=int(input("Enter the number of rotations:"))
n=len(arr)
d=d%n
i=0
j=d-1
while i<j:
    arr[i],arr[j]=arr[j],arr[i]
    i+=1
    j-=1
i=d
j=len(arr)-1
while(i<j):
    arr[i],arr[j]=arr[j],arr[i]
    i+=1
    j-=1

i=0
j=n-1
while(i<j):
    arr[i],arr[j]=arr[j],arr[i]
    i+=1
    j-=1
print(arr)
